# %% [markdown]
# PROJETO DE ALGORITMOS EM GRAFOS (GCC218)- Modelagem Logística com Grafos em Python
#
# Alunas: Lana da Silva Miranda, Nina Tobias Novikoff da Cunha Ribeiro

# %% [markdown]
# Importando funções do código principal:

# %%
import importlib
import proj
import time 

importlib.reload(proj)  # recarrega o arquivo proj.py
from proj import * # Para importar todas as funções

# %% [markdown]
# Leitura dos dados e inserção no grafo:

# %%
#arq_entrada = input("Digite o nome do arquivo: ")
#cabecalho, grafo = ler_entrada(arq_entrada)

# %% [markdown]
# Estatísticas:

# %%
#exportar_csv(cabecalho, grafo)

#from IPython.display import display

#styled_df_estatisticas = visualizar_estatisticas()
#display(styled_df_estatisticas)

# %% [markdown]
# Intermediação:

# %%
#intermediacao = calculo_intermediacao (grafo, cabecalho)

#for i in range(1, len(intermediacao)):
    #print(f"Vértice {i}: {intermediacao[i]}")

# %% [markdown]
# (OPCIONAL) Impressão das matrizes de caminho mais curto (distâncias) e de predecessores

# %%
#_, grafo = ler_entrada (arq_entrada)
#distancias, predecessores = floyd_warshall(grafo, cabecalho)

#print("Matriz de distâncias:")
#imprimir_matriz(distancias, usar_inf=True)

#print("\nMatriz de predecessores:")
#imprimir_matriz(predecessores)

# %%
import os
import traceback
import pandas as pd

pasta_entrada = "instancias"
pasta_saida = "solucoes"
os.makedirs(pasta_saida, exist_ok=True)

arquivos = [f for f in os.listdir(pasta_entrada) if f.endswith(".dat")]

for arq in arquivos:
    try:
        print(f"🟡 Processando {arq}...")
        caminho = os.path.join(pasta_entrada, arq)
        processar_instancia(caminho, pasta_saida)
        print(f"✅ {arq} processado com sucesso.\n")
    except Exception as e:
        print(f"❌ ERRO ao processar {arq}: {e}")
        traceback.print_exc()
        print("\n---\n")

df = pd.DataFrame(estatisticas_gerais)
df.to_csv("estatisticas_gerais.csv", index=False, sep=';', encoding='utf-8')
print("✅ Planilha estatisticas_gerais.csv salva com sucesso!")
# Out:
# 🟡 Processando BHW1.dat...
# ✅ BHW1.dat processado com sucesso.
#
# 🟡 Processando BHW10.dat...
# ✅ BHW10.dat processado com sucesso.
#
# 🟡 Processando BHW11.dat...
# ✅ BHW11.dat processado com sucesso.
#
# 🟡 Processando BHW12.dat...
# ✅ BHW12.dat processado com sucesso.
#
# 🟡 Processando BHW13.dat...
# ✅ BHW13.dat processado com sucesso.
#
# 🟡 Processando BHW14.dat...
# ✅ BHW14.dat processado com sucesso.
#
# 🟡 Processando BHW15.dat...
# ✅ BHW15.dat processado com sucesso.
#
# 🟡 Processando BHW16.dat...
# ✅ BHW16.dat processado com sucesso.
#
# 🟡 Processando BHW17.dat...
# ✅ BHW17.dat processado com sucesso.
#
# 🟡 Processando BHW18.dat...
# ✅ BHW18.dat processado com sucesso.
#
# 🟡 Processando BHW19.dat...
# ✅ BHW19.dat processado com sucesso.
#
# 🟡 Processando BHW2.dat...
# ✅ BHW2.dat processado com sucesso.
#
# 🟡 Processando BHW20.dat...
# ✅ BHW20.dat processado com sucesso.
#
# 🟡 Processando BHW3.dat...
# ✅ BHW3.dat processado com sucesso.
#
# 🟡 Processando BHW4.dat...
# ✅ BHW4.dat processado com sucesso.
#
# 🟡 Processando BHW5.dat...
# ✅ BHW5.dat processado com sucesso.
#
# 🟡 Processando BHW6.dat...
# ✅ BHW6.dat processado com sucesso.
#
# 🟡 Processando BHW7.dat...
# ✅ BHW7.dat processado com sucesso.
#
# 🟡 Processando BHW8.dat...
# ✅ BHW8.dat processado com sucesso.
#
# 🟡 Processando BHW9.dat...
# ✅ BHW9.dat processado com sucesso.
#
# 🟡 Processando CBMix1.dat...
# ✅ CBMix1.dat processado com sucesso.
#
# 🟡 Processando CBMix10.dat...
# ✅ CBMix10.dat processado com sucesso.
#
# 🟡 Processando CBMix11.dat...
# ✅ CBMix11.dat processado com sucesso.
#
# 🟡 Processando CBMix12.dat...
# ✅ CBMix12.dat processado com sucesso.
#
# 🟡 Processando CBMix13.dat...
# ✅ CBMix13.dat processado com sucesso.
#
# 🟡 Processando CBMix14.dat...
# ✅ CBMix14.dat processado com sucesso.
#
# 🟡 Processando CBMix15.dat...
# ✅ CBMix15.dat processado com sucesso.
#
# 🟡 Processando CBMix16.dat...
# ✅ CBMix16.dat processado com sucesso.
#
# 🟡 Processando CBMix17.dat...
# ✅ CBMix17.dat processado com sucesso.
#
# 🟡 Processando CBMix18.dat...
# ✅ CBMix18.dat processado com sucesso.
#
# 🟡 Processando CBMix19.dat...
# ✅ CBMix19.dat processado com sucesso.
#
# 🟡 Processando CBMix2.dat...
# ✅ CBMix2.dat processado com sucesso.
#
# 🟡 Processando CBMix20.dat...
# ✅ CBMix20.dat processado com sucesso.
#
# 🟡 Processando CBMix21.dat...
# ✅ CBMix21.dat processado com sucesso.
#
# 🟡 Processando CBMix22.dat...
# ✅ CBMix22.dat processado com sucesso.
#
# 🟡 Processando CBMix23.dat...
# ✅ CBMix23.dat processado com sucesso.
#
# 🟡 Processando CBMix3.dat...
# ✅ CBMix3.dat processado com sucesso.
#
# 🟡 Processando CBMix4.dat...
# ✅ CBMix4.dat processado com sucesso.
#
# 🟡 Processando CBMix5.dat...
# ✅ CBMix5.dat processado com sucesso.
#
# 🟡 Processando CBMix6.dat...
# ✅ CBMix6.dat processado com sucesso.
#
# 🟡 Processando CBMix7.dat...
# ✅ CBMix7.dat processado com sucesso.
#
# 🟡 Processando CBMix8.dat...
# ✅ CBMix8.dat processado com sucesso.
#
# 🟡 Processando CBMix9.dat...
# ✅ CBMix9.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n240-Q16k.dat...
# ✅ DI-NEARP-n240-Q16k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n240-Q2k.dat...
# ✅ DI-NEARP-n240-Q2k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n240-Q4k.dat...
# ✅ DI-NEARP-n240-Q4k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n240-Q8k.dat...
# ✅ DI-NEARP-n240-Q8k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n422-Q16k.dat...
# ✅ DI-NEARP-n422-Q16k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-n422-Q2k.dat...
# ✅ DI-NEARP-n422-Q2k.dat processado com sucesso.
#
# 🟡 Processando DI-NEARP-
.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_2C.dat...
# ✅ mgval_0.45_2C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_3A.dat...
# ✅ mgval_0.45_3A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_3B.dat...
# ✅ mgval_0.45_3B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_3C.dat...
# ✅ mgval_0.45_3C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_4A.dat...
# ✅ mgval_0.45_4A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_4B.dat...
# ✅ mgval_0.45_4B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_4C.dat...
# ✅ mgval_0.45_4C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_4D.dat...
# ✅ mgval_0.45_4D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_5A.dat...
# ✅ mgval_0.45_5A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_5B.dat...
# ✅ mgval_0.45_5B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_5C.dat...
# ✅ mgval_0.45_5C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_5D.dat...
# ✅ mgval_0.45_5D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_6A.dat...
# ✅ mgval_0.45_6A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_6B.dat...
# ✅ mgval_0.45_6B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_6C.dat...
# ✅ mgval_0.45_6C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_7A.dat...
# ✅ mgval_0.45_7A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_7B.dat...
# ✅ mgval_0.45_7B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_7C.dat...
# ✅ mgval_0.45_7C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_8A.dat...
# ✅ mgval_0.45_8A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_8B.dat...
# ✅ mgval_0.45_8B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_8C.dat...
# ✅ mgval_0.45_8C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_9A.dat...
# ✅ mgval_0.45_9A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_9B.dat...
# ✅ mgval_0.45_9B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_9C.dat...
# ✅ mgval_0.45_9C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.45_9D.dat...
# ✅ mgval_0.45_9D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_10A.dat...
# ✅ mgval_0.50_10A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_10B.dat...
# ✅ mgval_0.50_10B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_10C.dat...
# ✅ mgval_0.50_10C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_10D.dat...
# ✅ mgval_0.50_10D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_1A.dat...
# ✅ mgval_0.50_1A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_1B.dat...
# ✅ mgval_0.50_1B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_1C.dat...
# ✅ mgval_0.50_1C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_2A.dat...
# ✅ mgval_0.50_2A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_2B.dat...
# ✅ mgval_0.50_2B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_2C.dat...
# ✅ mgval_0.50_2C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_3A.dat...
# ✅ mgval_0.50_3A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_3B.dat...
# ✅ mgval_0.50_3B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_3C.dat...
# ✅ mgval_0.50_3C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_4A.dat...
# ✅ mgval_0.50_4A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_4B.dat...
# ✅ mgval_0.50_4B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_4C.dat...
# ✅ mgval_0.50_4C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_4D.dat...
# ✅ mgval_0.50_4D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_5A.dat...
# ✅ mgval_0.50_5A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_5B.dat...
# ✅ mgval_0.50_5B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_5C.dat...
# ✅ mgval_0.50_5C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_5D.dat...
# ✅ mgval_0.50_5D.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_6A.dat...
# ✅ mgval_0.50_6A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_6B.dat...
# ✅ mgval_0.50_6B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_6C.dat...
# ✅ mgval_0.50_6C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_7A.dat...
# ✅ mgval_0.50_7A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_7B.dat...
# ✅ mgval_0.50_7B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_7C.dat...
# ✅ mgval_0.50_7C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_8A.dat...
# ✅ mgval_0.50_8A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_8B.dat...
# ✅ mgval_0.50_8B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_8C.dat...
# ✅ mgval_0.50_8C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_9A.dat...
# ✅ mgval_0.50_9A.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_9B.dat...
# ✅ mgval_0.50_9B.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_9C.dat...
# ✅ mgval_0.50_9C.dat processado com sucesso.
#
# 🟡 Processando mgval_0.50_9D.dat...
# ✅ mgval_0.50_9D.dat processado com sucesso.
#
# ✅ Planilha estatisticas_gerais.csv salva com sucesso!
